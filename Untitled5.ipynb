# %% [markdown]
# <a href="https://colab.research.google.com/github/NoelPaulMailakkal/Business-Analytics-with-Python/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("Sample - Superstore.xlsx")

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.Sales.max()
# Out:
# 22638.48

# %%
df.Sales.min()
# Out:
# 0.44399999999999995

# %%
df.Sales.mean()
# Out:
# 229.8580008304938

# %%
df.groupby("Quantity").max()
# Out:
#           Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# Quantity
# 1           9988  US-2017-167920 2017-12-29 2018-01-03  Standard Class
# 2           9994  US-2017-169551 2017-12-30 2018-01-05  Standard Class
# 3           9990  US-2017-169551 2017-12-30 2018-01-04  Standard Class
# 4           9993  US-2017-168802 2017-12-30 2018-01-04  Standard Class
# 5           9989  US-2017-169502 2017-12-29 2018-01-02  Standard Class
# 6           9948  US-2017-167402 2017-12-28 2017-12-31  Standard Class
# 7           9983  US-2017-165344 2017-12-30 2018-01-04  Standard Class
# 8           9949  US-2017-158526 2017-12-29 2018-01-05  Standard Class
# 9           9943  US-2017-166688 2017-12-25 2018-01-01  Standard Class
# 10          9985  US-2017-165344 2017-12-04 2017-12-09  Standard Class
# 11          9896  US-2017-142188 2017-11-28 2017-12-02  Standard Class
# 12          8871  US-2017-110576 2017-12-01 2017-12-06  Standard Class
# ...

# %%
df.groupby("Quantity").min()
# Out:
#           Row ID        Order ID Order Date  Ship Date    Ship Mode  \
# Quantity
# 1             53  CA-2014-100328 2014-01-06 2014-01-10  First Class
# 2              1  CA-2014-100363 2014-01-03 2014-01-07  First Class
# 3              2  CA-2014-100006 2014-01-04 2014-01-07  First Class
# 4              7  CA-2014-100762 2014-01-06 2014-01-10  First Class
# 5              4  CA-2014-100860 2014-01-13 2014-01-17  First Class
# 6              8  CA-2014-100090 2014-01-13 2014-01-15  First Class
# 7              6  CA-2014-101392 2014-01-07 2014-01-12  First Class
# 8             68  CA-2014-104780 2014-01-26 2014-01-31  First Class
# 9             11  CA-2014-102673 2014-01-06 2014-01-10  First Class
# 10           330  CA-2014-111871 2014-01-19 2014-01-20  First Class
# 11           148  CA-2014-115049 2014-04-19 2014-04-23  First Class
# 12           344  CA-2014-102673 2014-03-14 2014-03-19  First Class
# 13           252  CA-2014-101364 2014-01-26 2014-01-31  First Class
# ...

# %%
df.groupby("Quantity").mean()
# Out:
#                Row ID   Postal Code        Sales  Discount      Profit
# Quantity
# 1         4916.078977  53740.661846    59.234632  0.152959    8.276396
# 2         5058.148626  55136.025396   120.354488  0.154858   16.006831
# 3         4957.404317  54924.250311   175.201578  0.153329   23.667715
# 4         4959.047019  54862.481948   271.764059  0.157708   37.131310
# 5         5193.270732  56694.857724   337.936339  0.157146   40.257394
# 6         5021.608392  55051.805944   362.101960  0.166556   18.051517
# 7         4770.217822  55723.661716   395.888393  0.161980   56.579163
# 8         4714.712062  56692.369650   458.210802  0.171595   42.244342
# 9         4992.771318  54736.406977   498.083683  0.147946   68.557716
# 10        5365.754386  55343.105263   422.046737  0.190702   35.862404
# 11        5420.294118  55274.764706   463.896529  0.097059  126.275503
# 12        4641.608696  68679.130435   646.452522  0.113043   51.524609
# ...

# %%
df.groupby("Ship Mode").max()
# Out:
#                 Row ID        Order ID Order Date  Ship Date Customer ID  \
# Ship Mode
# First Class       9982  US-2017-169551 2017-12-29 2017-12-31    ZD-21925
# Same Day          9964  US-2017-168116 2017-12-27 2017-12-27    ZD-21925
# Second Class      9994  US-2017-169320 2017-12-29 2018-01-02    ZD-21925
# Standard Class    9993  US-2017-169502 2017-12-30 2018-01-05    ZD-21925
#
#                      Customer Name      Segment        Country        City  \
# Ship Mode
# First Class     Zuschuss Donatelli  Home Office  United States  Woonsocket
# Same Day        Zuschuss Donatelli  Home Office  United States        Yuma
# Second Class    Zuschuss Donatelli  Home Office  United States        Yuma
# Standard Class  Zuschuss Donatelli  Home Office  United States        Yuma
#
#                     State  Postal Code Region       Product ID    Category  \
# Ship Mode
# First Class     Wisconsin        99207   West  TEC-PH-10004977  Technology
# ...

# %%
df.groupby("Ship Mode").min()
# Out:
#                 Row ID        Order ID Order Date  Ship Date Customer ID  \
# Ship Mode
# First Class         36  CA-2014-101147 2014-01-06 2014-01-07    AA-10315
# Same Day           367  CA-2014-105249 2014-02-18 2014-02-18    AA-10480
# Second Class         1  CA-2014-100706 2014-01-06 2014-01-08    AA-10375
# Standard Class       4  CA-2014-100006 2014-01-03 2014-01-07    AA-10315
#
#                 Customer Name   Segment        Country         City    State  \
# Ship Mode
# First Class     Aaron Bergman  Consumer  United States      Abilene  Alabama
# Same Day            Adam Hart  Consumer  United States  Albuquerque  Alabama
# Second Class    Aaron Hawkins  Consumer  United States     Aberdeen  Alabama
# Standard Class  Aaron Bergman  Consumer  United States        Akron  Alabama
#
#                 Postal Code   Region       Product ID   Category Sub-Category  \
# Ship Mode
# First Class            1810  Central  FUR-BO-10000112  Furniture  Accessories
# ...

# %%
df.groupby("Ship Mode").mean()
# Out:
#                      Row ID   Postal Code       Sales  Quantity  Discount  \
# Ship Mode
# First Class     4875.510403  54765.611834  228.497024  3.701560  0.164610
# Same Day        5128.909761  57536.082873  236.396179  3.609576  0.152394
# Second Class    4936.759383  55626.009254  236.089239  3.816452  0.138895
# Standard Class  5036.776977  54944.447051  227.583067  3.819873  0.160023
#
#                    Profit
# Ship Mode
# First Class     31.839948
# Same Day        29.266591
# Second Class    29.535545
# Standard Class  27.494770

# %%
df.groupby("State").mean()
# Out:
#                            Row ID   Postal Code        Sales  Quantity  \
# State
# Alabama               3997.967213  35994.573770   319.846557  4.196721
# Arizona               4553.017857  85277.348214   157.508933  3.848214
# Arkansas              5076.250000  72321.816667   194.635500  4.000000
# California            5066.191404  92145.246877   228.729451  3.831584
# Colorado              4379.131868  80295.758242   176.418231  3.807692
# Connecticut           5419.646341   6475.670732   163.223866  3.426829
# Delaware              5253.854167  19755.250000   285.948635  3.822917
# District of Columbia  1791.800000  20016.000000   286.502000  4.000000
# Florida               5112.937337  33003.198433   233.612815  3.600522
# Georgia               4802.119565  30899.347826   266.825217  3.831522
# Idaho                 6163.190476  83462.333333   208.689810  3.047619
# Illinois              5226.587398  60719.048780   162.939230  3.750000
# ...

# %%
df.groupby("State").Sales.mean()
# Out:
# State
# Alabama                  319.846557
# Arizona                  157.508933
# Arkansas                 194.635500
# California               228.729451
# Colorado                 176.418231
# Connecticut              163.223866
# Delaware                 285.948635
# District of Columbia     286.502000
# Florida                  233.612815
# Georgia                  266.825217
# Idaho                    208.689810
# Illinois                 162.939230
# Indiana                  359.431946
# Iowa                     152.658667
# Kansas                   121.429583
# Kentucky                 263.250000
# Louisiana                219.453095
# Maine                    158.816250
# Maryland                 225.766886
# Massachusetts            212.106919
# Michigan                 299.096525
# Minnesota                335.541011
# Mississippi              203.232830
# Missouri                 336.441667
# Montana                  372.623467
# Nebraska                 196.445526
# ...

# %%
df.loc[df["Ship Mode"]=="Second Class"]
# Out:
#       Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1          2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2          3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
# 17        18  CA-2014-167164 2014-05-13 2014-05-15  Second Class    AG-10270
# 18        19  CA-2014-143336 2014-08-27 2014-09-01  Second Class    ZD-21925
# ...      ...             ...        ...        ...           ...         ...
# 9965    9966  CA-2016-146374 2016-12-05 2016-12-10  Second Class    HE-14800
# 9966    9967  CA-2016-146374 2016-12-05 2016-12-10  Second Class    HE-14800
# 9980    9981  US-2015-151435 2015-09-06 2015-09-09  Second Class    SW-20455
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23  Second Class    TB-21400
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("Supermarket_sales.csv")

# %%
df
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
df.groupby("Productline").Unitprice.min()
# Out:
# Productline
# Electronic accessories    10.56
# Fashion accessories       10.18
# Food and beverages        10.13
# Health and beauty         10.08
# Home and lifestyle        10.53
# Sports and travel         10.17
# Name: Unitprice, dtype: float64

# %%
df.groupby("Productline").Unitprice.max()
# Out:
# Productline
# Electronic accessories    99.73
# Fashion accessories       99.89
# Food and beverages        99.79
# Health and beauty         99.96
# Home and lifestyle        99.92
# Sports and travel         99.96
# Name: Unitprice, dtype: float64

# %%
df.groupby("Productline").Unitprice.mean()
# Out:
# Productline
# Electronic accessories    53.551588
# Fashion accessories       57.153652
# Food and beverages        56.008851
# Health and beauty         54.854474
# Home and lifestyle        55.316937
# Sports and travel         56.993253
# Name: Unitprice, dtype: float64

# %%
df.loc[(df['Gender']== "Male") & (df['Productline']== "Health and beauty")]
# Out:
#       No    InvoiceID Branch       City Customertype Gender  \
# 3      4  123-19-1176      A     Yangon       Member   Male
# 21    22  371-85-5789      B   Mandalay       Normal   Male
# 29    30  848-62-7243      A     Yangon       Normal   Male
# 33    34  595-11-5460      A     Yangon       Normal   Male
# 44    45  617-15-4209      C  Naypyitaw       Member   Male
# ..   ...          ...    ...        ...          ...    ...
# 981  982  809-46-1866      A     Yangon       Normal   Male
# 983  984  148-41-7930      C  Naypyitaw       Normal   Male
# 987  988  552-44-5977      B   Mandalay       Member   Male
# 989  990  430-53-4718      B   Mandalay       Member   Male
# 995  996  233-67-5758      C  Naypyitaw       Normal   Male
#
#            Productline  Unitprice  Quantity      Tax     Total       Date  \
# 3    Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 21   Health and beauty      87.98         3  13.1970  277.1370   3/5/2019
# ...

# %%
df.loc[(df['Gender']== "Female") & (df['Productline']== "Fashion accessories")]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 10     11  351-62-0822      B   Mandalay       Member  Female
# 27     28  189-17-4241      A     Yangon       Normal  Female
# 49     50  574-22-5561      C  Naypyitaw       Member  Female
# 52     53  616-24-2851      B   Mandalay       Member  Female
# 67     68  109-28-2512      B   Mandalay       Member  Female
# ..    ...          ...    ...        ...          ...     ...
# 931   932  756-93-1854      C  Naypyitaw       Member  Female
# 955   956  846-10-0341      A     Yangon       Normal  Female
# 962   963  593-08-5916      A     Yangon       Normal  Female
# 985   986  374-38-5555      B   Mandalay       Normal  Female
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax     Total       Date  \
# 10   Fashion accessories      14.48         4   2.8960   60.8160   2/6/2019
# ...

# %%
df.loc[(df['Productline']== "Fashion accessories") | (df['Productline']== "Sports and travel") & (df['Gender']== "Female")]
# Out:
#        No    InvoiceID Branch      City Customertype  Gender  \
# 10     11  351-62-0822      B  Mandalay       Member  Female
# 15     16  299-46-1805      B  Mandalay       Member  Female
# 26     27  649-29-6775      B  Mandalay       Normal    Male
# 27     28  189-17-4241      A    Yangon       Normal  Female
# 30     31  871-79-8483      B  Mandalay       Normal    Male
# ..    ...          ...    ...       ...          ...     ...
# 982   983  139-32-4183      A    Yangon       Member  Female
# 985   986  374-38-5555      B  Mandalay       Normal  Female
# 991   992  602-16-6955      B  Mandalay       Normal  Female
# 993   994  690-01-6631      B  Mandalay       Normal    Male
# 999  1000  849-09-3807      A    Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax     Total       Date  \
# 10   Fashion accessories      14.48         4   2.8960   60.8160   2/6/2019
# 15     Sports and travel      93.72         6  28.1160  590.4360  1/15/2019
# ...

# %%
import matplotlib.pyplot as plt

# %%
x=df["Quantity"]
y=df["Tax"]
plt.plot(x,y)
plt.show()

# %%
plt.plot(df.Tax,df.Quantity)
